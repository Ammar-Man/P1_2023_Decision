# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import sys
import matplotlib
matplotlib.use('Agg')

import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
path = "./USvideos.csv"
df = pd.read_csv(path ,  sep = ',')
df.head(1)
# Out:
#       video_id trending_date                               title  \
# 0  2kyS6SvSYSE      17.14.11  WE WANT TO TALK ABOUT OUR MARRIAGE
#
#   channel_title  category_id              publish_time             tags  \
# 0  CaseyNeistat           22  2017-11-13T17:13:01.000Z  SHANtell martin
#
#     views  likes  dislikes  comment_count  \
# 0  748374  57527      2966          15954
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
#
#    ratings_disabled  video_error_or_removed  \
# 0             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...

# %%
from sklearn.preprocessing import MinMaxScaler
datatypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
normarization = df.select_dtypes(include=datatypes)
for col in normarization.columns:
    MinMaxScaler(col)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10)
features = kmeans.fit_predict(normarization)
df['features'] = features
MinMaxScaler(df['features'])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# MinMaxScaler(feature_range=0        0
# 1        4
# 2        4
# 3        0
# 4        4
#         ..
# 40944    4
# 40945    0
# 40946    0
# 40947    9
# 40948    8
# Name: features, Length: 40949, dtype: int32)

# %%
path = "./USvideos.csv"
df2 = pd.read_csv(path ,  sep = ',')
df2.columns

search_string = 'WE WANT TO TALK ABOUT OUR MARRIAGE'
filtered_df = df2[df2['title'].str.contains(search_string, case=False, na=False)]


class Spotify_Recommendation():
    def __init__(self, dataset):
        self.dataset = dataset

    def recommend(self, songs, amount=1):
        distance = []
        rec = self.dataset[self.dataset.title.str.lower() != songs.lower()]  # Filter out the input song
        
        # Check if there are songs left after filtering
        if rec.empty:
            print("No matching songs found in the dataset.")
            return None  # or handle the empty case accordingly
        
        song = rec.head(1).values[0]
# your videos columns id bystring
        for song_row in tqdm(rec.values):
            d = 0
            for col_idx, col_value in enumerate(song):
                if col_idx not in [1, 6, 12, 14, 18] and pd.api.types.is_numeric_dtype(rec.iloc[:, col_idx]):
                    d = d + np.absolute(float(col_value) - float(song_row[col_idx]))
# if else your videos columns id by numbers
            # for col in np.arange(len(rec.columns)):
            #     if col not in [1, 6, 12, 14, 18]:
            #         d = d + np.absolute(float(song[col]) - float(song_row[col]))
            distance.append(d)
        
        rec['distance'] = distance
        rec = rec.sort_values('distance')
        columns = ['channel_title', 'title','thumbnail_link','likes','tags']
        return rec[columns][:amount]

# Assuming df2 is your DataFrame
recommendations = Spotify_Recommendation(df2)
recommendations.recommend("WE WANT TO TALK ABOUT OUR MARRIAGE", 10)
# Out:
# 100%|██████████| 40942/40942 [00:31<00:00, 1311.80it/s]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7668\3656009972.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['distance'] = distance
#               channel_title  \
# 1           LastWeekTonight
# 29045           jeffreestar
# 14509           PlayStation
# 26990  Marvel Entertainment
# 29340           AlishaMarie
# 26740    Casually Explained
# 32433        First We Feast
# 37847               LaurDIY
# 30797       Rosanna Pansino
# 36388              FaZe Rug
#
#                                                    title  \
# 1      The Trump Presidency: Last Week Tonight with J...
# 29045  *NEW* FENTY BEAUTY BODY LAVA & FAIRY BOMB | HI...
# 14509                   God of War – Story Trailer | PS4
# 26990  Marvel Studios' Avengers: Infinity War - All o...
# 29340       Funny Pranks for April Fools!! Roommate Wars
# 26740                  Casually Explained: Men's Fashion
# 32433  Alton Brown Rigorously Reviews Spicy Wings | H...
# 37847                         DOLLAR STORE DIY CHALLENGE
# 30797                           Whats In My HUGE Fridge?
# 36388  I pranked him... then I BOUGHT him his DREAM C...
#
#                                        thumbnail_link   likes  \
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg   97185
# 29045  https://i.ytimg.com/vi/XWrB4qOF_UA/default.jpg  106142
# 14509  https://i.ytimg.com/vi/K0u_kAWLJOA/default.jpg   93363
# 26990  https://i.ytimg.com/vi/YZ1UN5gvLjQ/default.jpg   92615
# 29340  https://i.ytimg.com/vi/RiGFGXd9Xvs/default.jpg   96559
# 26740  https://i.ytimg.com/vi/KyQyz2upSgY/default.jpg  101226
# 32433  https://i.ytimg.com/vi/T1-k7VYwsHg/default.jpg   88076
# 37847  https://i.ytimg.com/vi/M79o2UejYKo/default.jpg   95997
# 30797  https://i.ytimg.com/vi/we5djgQwK9w/default.jpg  100636
# 36388  https://i.ytimg.com/vi/2v4-L4PkV9U/default.jpg  109111
#
#                                                     tags
# 1      last week tonight trump presidency|"last week ...
# 29045  jeffree star|"body lava"|"fenty beauty"|"fenty...
# 14509  God of War|"Kratos"|"Atreus"|"E3 2017"|"E3"|"G...
# 26990  marvel|"comics"|"comic books"|"nerdy"|"geeky"|...
# 29340  Alisha Marie|"funny pranks"|"april fools"|"jok...
# 26740  streetwear|"men's fashion"|"male fashion"|"mal...
# 32433  First we feast|"fwf"|"firstwefeast"|"food"|"fo...
# 37847  DIY|"do it yourself"|"how to"|"laurDIY"|"laure...
# 30797  lifestyle|"tour"|"vlog"|"vlogger"|"fridge"|"or...
# 36388  faze rug|"rug"|"rugfaze"|"emotional"|"emotiona...
